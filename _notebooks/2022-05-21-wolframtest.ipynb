# %% [markdown]
# # WolframTest Notebook
# > A test ipython notebook through jupyter running the Wolfram Engine kernel.
#
# - toc:true
# - branch: master
# - badges: true
# - comments: true
# - author: Ashok Kumar
# - categories: [wolfram]

# %%
$Version
# Out:
# 13.0.1 for Microsoft Windows (64-bit) (January 28, 2022)

# %%
FullForm[a+b+c]
# Out:
# Plus[a, b, c]

# %%
FullForm[{a,b,c}]
# Out:
# List[a, b, c]

# %%
neg3=-w // TeXForm
# Out:
# \{-2,-3\}

# %%
w={2,3}
# Out:
# {2, 3}

# %%
fun:= Sin[Sqrt[x^2 + y^2]]/Sqrt[x^2 + y^2]
Plot3D[fun, {x, -5*Pi, 5*Pi}, {y, -5*Pi, 5*Pi},
    PlotPoints -> 100, BoxRatios -> {1, 1, 0.2},
    PlotRange -> All]
# Out:
# -Graphics3D-

# %%
$Version
# Out:
# 13.0.1 for Microsoft Windows (64-bit) (January 28, 2022)
